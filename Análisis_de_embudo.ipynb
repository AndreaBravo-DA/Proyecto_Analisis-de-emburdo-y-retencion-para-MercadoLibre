# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreaBravo-DA/Proyecto_Analisis-de-emburdo-y-retencion-para-MercadoLibre/blob/main/An%C3%A1lisis_de_embudo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Análisis de embudo y retención para MercadoLibre**

# %% [markdown]
# ## Introducción

# %% [markdown]
# Mapear el embudo de conversión, identificar los principales puntos de fuga y evaluar la retención de ususarios por cohortes.
#
# Etapa de perdida de usuarios: del perido [01/01/2025] al [08/31/2025].
#
# Retención de usuarios a lo largo del tiempo: del periodo [01/01/2025] al el [06/01/2025], en D7, D14, D21, D28.

# %% [markdown]
# ## Visualización de datos

# %% [markdown]
# #### 1. Cargar datos y vista rápida

# %% [markdown]
# #### Consultar el dataset y mostrar las primeras 5 filas
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Notas.**
#
# Las columnas de interés para el análisis del dataset son:
#
# * USUARIO: user_id
# * ETAPA: event_name
# * FECHA: (01/01/2025 al 08/31/2025) 	event_date
# * PAÍS: country

# %% [markdown]
# #### # Explorar el esquema y comprender el flujo
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
# ## Construcción de embudo

# %% [markdown]
# #### 2. Creación de CTE

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 3. Calcular conversiones entre etapas

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Nota.**
#
# Al realizar los bloques de usuarios por etapa de usuario y el periodo establecido, se obtienen los siguientes totales de usuarios.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Nota.**
#
# A partir de los conteos por etapa del embudo, se calcula el porcentaje de conversión desde la etapa inicial hacia cada etapa. Por lo que se obtuvo.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 4. Segmentar el Embudo General por país

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Nota.**
#
# A partir de agrupa las conversiones del embudo por país y detecta en que etapa del funnel se pierde más a los usuarios. Se obtuvo:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 5. Contar usuarios activos acumulados por país (D7, D14, D21, D28)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 6. Convertir conteos a % de retención por país

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Cohorte con la primer fecha de registro

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Calcular retención por cohorte y periodo D7, D14, D21, D28

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
